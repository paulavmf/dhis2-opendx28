# %%
# !pip install faker
# Out:
# ...
#      |████████████████████████████████| 1.7 MB 986 kB/s eta 0:00:01
# ...

# %%
import pandas as pd
import requests

# %% [markdown]
# ### Generación de datos para GNUHealth
#
# Apartir de datos de Kaggle sobre hospitales, combinados con el generador de datos falsos Faker se podrían generar datos. También se podrían generar más datos sintéticos a partir de estos.
#
# Puedo crear datos directamente para dhis2 o datos para gnuhealth...
#
# https://www.youtube.com/watch?v=7M2Q5wrqC7I
# https://www.youtube.com/watch?v=Ei0klF38CNs
#
#
# #### datos de Kaggle
# 1. Hospital Admision data
# https://www.kaggle.com/datasets/ashishsahani/hospital-admissions-data/download?datasetVersionNumber=1   datasets/hospital-admissions-data
#
#
#
# 2. Casos de Malaria en Africa
#
# https://www.kaggle.com/datasets/lydia70/malaria-in-africa?select=DatasetAfricaMalaria.csv
# datasets/DatasetAfricaMalaria.csv

# %%
# !ls datasets/hospital-admission-data/
# Out:
# 'HDHI Admission data.csv'  'HDHI Pollution Data.csv'
# 'HDHI Mortality Data.csv'   table_headings.csv

# %%
file = "datasets/hospital-admission-data/table_headings.csv"
data = pd.read_csv(file)

# %%
data.dropna(inplace= True)
data
# Out:
#                       Table Heading  \
# 0                               SNO
# 1                           MRD No.
# 2                             D.O.A
# 3                             D.O.D
# 4                               AGE
# 5                            GENDER
# 6                             RURAL
# 7   TYPE OF ADMISSION-EMERGENCY/OPD
# 8                        month year
# 9                  DURATION OF STAY
# 10  duration of intensive unit stay
# 11                          OUTCOME
# 12                         SMOKING
# 13                          ALCOHOL
# 14                               DM
# 15                              HTN
# 16                              CAD
# 17                        PRIOR CMP
# 18                              CKD
# 19                               HB
# 20                              TLC
# 21                        PLATELETS
# 22                          GLUCOSE
# 23                             UREA
# 24                       CREATININE
# ...

# %%
from faker import Faker

# %%
f = Faker(["fr_FR"])

# %%
f.sentences()
# Out:
# ["Apercevoir aujourd'hui peu curieux beaux rapidement.",
#  'Quant À mémoire approcher voyage traiter patron.',
#  'Rapidement construire en conscience.']

# %%
f.month_name()
# Out:
# 'Décembre'
